# %%
import sys

import jax as jax

sys.path.append('..//')

import jax
import numpy as np
import jax.numpy as jnp
import matplotlib.pyplot as plt
from jax import jit
import time
import warnings

jax.config.update("jax_enable_x64", False)
jax.config.update("jax_platform_name", "gpu")

from parsmooth._base import MVNStandard, FunctionalModel, MVNSqrt
from parsmooth.linearization import cubature, extended
from parsmooth.methods import iterated_smoothing
from bearing_data import get_data, make_parameters

# %%
warnings.simplefilter("ignore")

# %%
s1 = jnp.array([-1.5, 0.5])  # First sensor location
s2 = jnp.array([1., 1.])  # Second sensor location
r = 0.5  # Observation noise (stddev)
x0 = jnp.array([0.1, 0.2, 1, 0])  # initial true location
dt = 0.01  # discretization time step
qc = 0.01  # discretization noise
qw = 0.1  # discretization noise

T = 5000
_, true_states, ys = get_data(x0, dt, r, T, s1, s2)
Q, R, observation_function, transition_function = make_parameters(qc, qw, r, dt, s1, s2)

chol_Q = jnp.linalg.cholesky(Q)
chol_R = jnp.linalg.cholesky(R)

m0 = jnp.array([-4., -1., 2., 7., 3.])
chol_P0 = jnp.eye(5)
P0 = jnp.eye(5)

init = MVNStandard(m0, P0)
chol_init = MVNSqrt(m0, chol_P0)

initial_states =  MVNStandard(jnp.repeat(jnp.array([[-1., -1., 6., 4., 2.]]),T + 1, axis=0),
                                                     jnp.repeat(jnp.eye(5).reshape(1, 5, 5), T + 1, axis=0))
initial_states_sqrt = MVNSqrt(jnp.repeat(jnp.array([[-1., -1., 6., 4., 2.]]),T + 1, axis=0),
                              jnp.repeat(jnp.eye(5).reshape(1, 5, 5), T + 1, axis=0))


sqrt_transition_model = FunctionalModel(transition_function, MVNSqrt(jnp.zeros((5,)), chol_Q))
transition_model = FunctionalModel(transition_function, MVNStandard(jnp.zeros((5,)), Q))

sqrt_observation_model = FunctionalModel(observation_function, MVNSqrt(jnp.zeros((2,)), chol_R))
observation_model = FunctionalModel(observation_function, MVNStandard(jnp.zeros((2,)), R))
# Out:
# 2021-11-17 19:26:06.489237: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:06.543484: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:06.593494: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:06.648752: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:06.699120: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:06.751273: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:07.508073: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:07.509658: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:08.913446: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:08.915123: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:08.978246: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:09.024306: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:09.076212: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:09.125008: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:09.174004: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:09.242533: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:09.329290: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:09.397116: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:09.450917: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.

# %% [markdown]
# # Cubature

# %%
def cubature_sqrt_seq(y, initial_points_sqrt, iteration):
    sqrt_seq_res = iterated_smoothing(y, chol_init, sqrt_transition_model, sqrt_observation_model,
                                      cubature, initial_points_sqrt, False,
                                      criterion=lambda i, *_: i < iteration)
    return sqrt_seq_res


def cubature_sqrt_par(y, initial_points_sqrt, iteration):
    sqrt_par_res = iterated_smoothing(y, chol_init, sqrt_transition_model, sqrt_observation_model,
                                      cubature, initial_points_sqrt, True,
                                      criterion=lambda i, *_: i < iteration)
    return sqrt_par_res


def cubature_std_seq(y, initial_points, iteration):
    std_seq_res = iterated_smoothing(y, init, transition_model, observation_model,
                                     cubature, initial_points, False,
                                     criterion=lambda i, *_: i < iteration)
    return std_seq_res


def cubature_std_par(y, initial_points, iteration):
    std_par_res = iterated_smoothing(y, init, transition_model, observation_model,
                                     cubature, initial_points, True,
                                     criterion=lambda i, *_: i < iteration)
    return std_par_res

# %%
def func(method, lengths, n_runs=100, n_iter=10, sqrt=False):
    res_mean = []
    res_median = []
    for k, j in enumerate(lengths):
        print(f"Iteration {k+1} out of {len(lengths)}", end="\r")
        observations_slice = ys[:j]
        
        if sqrt:
            init_linearizations_points_slice = initial_states_sqrt.mean[:j+1]
            init_linearizations_chols_slice = initial_states_sqrt.chol[:j+1]
            init_linearizations_states = MVNSqrt(init_linearizations_points_slice, init_linearizations_chols_slice)
            args = observations_slice, init_linearizations_states, n_iter
        else:
            init_linearizations_points_slice = initial_states.mean[:j+1]
            init_linearizations_covs_slice = initial_states.cov[:j+1]
            init_linearizations_states = MVNStandard(init_linearizations_points_slice, init_linearizations_covs_slice)
            args = observations_slice, init_linearizations_states, n_iter
            
        s = method(*args)                
        s.mean.block_until_ready()
        run_times = []
        for _ in range(n_runs):
            tic = time.time()
            s_states = method(*args)
            s_states.mean.block_until_ready()
            toc = time.time()
            run_times.append(toc - tic)
        res_mean.append(np.mean(run_times))
        res_median.append(np.median(run_times))
    print()
    return np.array(res_mean), np.array(res_median)

# %%
lengths_space = np.logspace(2, int(np.log2(T)), num=10, base=2, dtype=int)

# %%
gpu_cubature_sqrt_par = jit(cubature_sqrt_par, backend="gpu")
gpu_cubature_sqrt_seq = jit(cubature_sqrt_seq, backend="gpu")
gpu_cubature_std_seq = jit(cubature_std_seq, backend="gpu")
gpu_cubature_std_par = jit(cubature_std_par, backend="gpu")

# %%
warnings.filterwarnings("ignore")

gpu_cubature_sqrt_par_mean_time, gpu_cubature_sqrt_par_median_time = func(gpu_cubature_sqrt_par, lengths_space, sqrt=True)
# Out:
# Iteration 1 out of 10
# 2021-11-17 19:26:09.585181: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:09.646719: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:33.941748: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:33.983955: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.100627: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.106777: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.108043: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.112274: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.114546: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.127379: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.134991: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.140939: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.148722: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.157696: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.165520: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.176128: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.181546: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.185814: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.186005: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.187069: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.188983: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.189201: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.190369: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.191503: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.192105: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.192337: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.193076: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.194775: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.197963: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.199219: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.201805: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.204531: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.204883: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.209555: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.209770: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.210289: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.211128: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.211884: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.212806: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.213521: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.214508: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.215919: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.216278: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.216833: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.216856: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.218105: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.218255: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.219126: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.219360: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.220950: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.222572: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.224419: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.225022: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.226779: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.227091: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.230060: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.230575: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.233455: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.234092: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.235399: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.235602: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.236228: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.236807: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.237120: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.238930: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.239399: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.239856: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.240201: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.241429: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.241839: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.242342: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.243181: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.243240: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.243355: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.243691: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.243885: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.243956: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.244079: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.244521: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.244922: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.245815: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.247971: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.248139: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.248248: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.251868: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.253494: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.256062: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.258393: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.258561: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.259773: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.261055: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.266131: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.267074: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.268943: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.270698: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.271188: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.274491: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.285658: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.286166: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:39.326262: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# Iteration 2 out of 10
# 2021-11-17 19:26:45.959793: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:26:46.029870: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.405656: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.410862: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.411545: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.415662: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.416162: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.417909: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.420661: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.421316: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.425605: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.426253: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.426743: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.430485: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.430956: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.433312: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.439816: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.449833: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.479397: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.481776: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.486000: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.515635: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.576018: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.581975: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.662869: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:27:26.697007: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# ...
# 2021-11-17 19:47:22.313573: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.321908: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.323331: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.329723: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.330946: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.338268: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.338452: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.340006: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.345671: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.345860: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.346452: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.346981: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.351826: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.352766: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.352898: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.358298: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.365599: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.365825: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.366524: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.367115: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.369677: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.371428: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.372551: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.374020: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.379185: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.383640: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.386392: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.386816: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.387590: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.393017: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.393825: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.394980: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.396018: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.399277: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.404777: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.405108: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.407897: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.417162: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.430041: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.467000: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.472295: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:47:22.505636: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.

# %%
warnings.filterwarnings("ignore")
gpu_cubature_sqrt_seq_mean_time, gpu_cubature_sqrt_seq_median_time = func(gpu_cubature_sqrt_seq, lengths_space, sqrt = True)
# Out:
# Iteration 1 out of 10
# 2021-11-17 19:48:05.137937: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.140688: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.142721: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.146489: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.150543: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.162287: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.162546: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.163766: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.167375: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.167492: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.168377: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.171125: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.172800: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.173035: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.175030: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.175886: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.176211: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.176410: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.177938: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.179297: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.179843: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.180300: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.180425: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.181314: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.181734: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.181766: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.183795: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.184061: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.185847: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.186963: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.187964: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.188415: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.188783: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.189074: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.189657: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.190178: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.193337: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.195447: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.195884: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.196462: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.196894: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.197141: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.197352: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.197449: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.197769: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.197855: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.198445: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.198558: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.198652: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.198844: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.198869: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.198914: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.198985: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.199009: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.199047: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.199198: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.200567: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.201718: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.202162: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.202471: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.203378: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.203480: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.203737: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.203845: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.203971: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.204140: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.204583: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.204774: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.204916: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.205461: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.206970: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.207664: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.208804: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.208938: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.209227: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.209357: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.209860: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.210089: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.210417: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.211142: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.211816: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.211896: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.212730: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.213178: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.213749: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.217525: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.217635: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.219624: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.223482: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.229138: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.235525: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.238284: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.240307: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.240752: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.245945: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:05.287596: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# Iteration 2 out of 10
# 2021-11-17 19:48:47.041375: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.046947: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.057178: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.057739: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.057906: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.059732: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.060413: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.060794: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.061034: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.061128: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.061496: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.061811: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.061954: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.064877: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.065348: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.065974: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.066228: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.066696: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.067592: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.067622: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.067921: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.068023: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.069113: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.069188: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.070044: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.070305: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.070566: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.071254: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.072658: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-17 19:48:47.072686: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# ...
# 2021-11-18 02:01:29.623009: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.623256: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.623278: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.623399: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.624269: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.624463: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.624599: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.625015: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.625253: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.625513: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.625931: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.626459: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.626854: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.627013: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.627119: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.627259: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.627476: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.627686: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.630963: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.632202: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.632406: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.632969: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.633562: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.634112: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.634969: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.635078: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.636370: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.639636: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.642450: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.644553: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.650948: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.652664: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.652711: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.662911: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.665085: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.667033: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.667685: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.683209: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.684489: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.687478: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.697315: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 02:01:29.697885: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.

# %%
warnings.filterwarnings("ignore")
gpu_cubature_std_seq_mean_time, gpu_cubature_std_seq_median_time = func(gpu_cubature_std_seq, lengths_space, sqrt = False)
# Out:
# Iteration 1 out of 10
# 2021-11-18 08:08:03.938971: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.939381: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.940898: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.941649: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.941699: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.943687: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.943943: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.943986: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.944013: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.944416: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.944444: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.945370: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.946015: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.946381: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.946828: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.947378: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.947582: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.947751: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.948968: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.948992: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.949093: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.949245: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.949629: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.949800: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.949849: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.954884: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.954920: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.954949: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.955241: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.956088: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.956280: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.956488: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.956612: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.957471: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.957609: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.957729: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.957927: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.958111: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.958142: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.958540: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.959118: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.959473: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.960080: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.960315: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.960651: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.960887: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.961585: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.961827: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.962010: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.962118: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.962211: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.962512: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.962566: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.962824: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.963236: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.963437: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.963644: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.963715: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.963795: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.963864: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.963889: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.963953: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.964224: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.965766: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.966671: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.966957: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.967613: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.970583: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.971153: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.976482: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.978559: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.979655: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.981035: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.981511: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.987508: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.987659: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.987770: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.990434: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.992860: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.994052: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.998962: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:03.999339: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:04.000319: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:04.001179: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:04.006681: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:04.012192: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:04.019081: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:04.023904: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# Iteration 2 out of 10
# 2021-11-18 08:08:07.368394: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.371944: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.372362: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.372551: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.372750: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.372978: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.373041: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.373138: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.373756: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.374283: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.374486: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.374748: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.375331: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.375382: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.375415: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.376404: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.377034: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.377160: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.377783: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.377925: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.378103: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.378387: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.378545: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.379065: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.379594: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.379731: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.379921: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.380292: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.380399: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.380787: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.381275: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.381415: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.381428: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.381494: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.381569: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.381979: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.382457: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:08:07.382651: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# ...
# 2021-11-18 08:33:02.590544: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.590723: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.591472: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.591569: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.591979: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.592111: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.592343: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.592601: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.592879: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.593254: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.594353: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.594619: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.597187: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.600018: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.600178: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.602123: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.604929: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.605133: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.609361: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.613597: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.615027: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.620658: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.621912: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.622215: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.625612: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.625698: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.627194: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.628275: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.629774: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.629813: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.629834: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.631725: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.633019: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.634050: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.634954: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.635818: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.638960: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.645389: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.651288: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.655709: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.669234: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 08:33:02.692051: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.

# %%
warnings.filterwarnings("ignore")
gpu_cubature_std_par_mean_time, gpu_cubature_std_par_median_time = func(gpu_cubature_std_par, lengths_space, sqrt = False)
# Out:
# Iteration 1 out of 10
# 2021-11-18 09:02:53.787839: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.788993: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.790888: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.791515: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.791553: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.792056: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.792077: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.792129: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.792507: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.794036: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.797974: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.798131: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.798488: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.798678: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.798934: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.799615: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.799709: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.799913: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.800041: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.800425: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.802064: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.802109: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.802428: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.802763: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.804155: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.804183: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.804831: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.805237: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.805328: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.805641: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.805679: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.806372: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.806561: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.806598: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.806617: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.806671: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.806694: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.807531: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.807603: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.808101: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.808301: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.808561: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.809331: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.809378: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.809436: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.809474: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.812703: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.813184: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.813310: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.813482: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.814936: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.815697: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.815782: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.815884: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.815902: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.816262: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.816642: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.819567: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.819754: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.820162: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.821950: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.822816: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.823046: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.823549: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.824756: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.825152: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.826029: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.827638: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.828604: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.828719: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.835241: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.835876: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.836577: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.836810: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.836972: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.838308: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.839703: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.840025: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.840152: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.840513: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.843115: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.848620: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.849406: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.856256: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.856580: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.858017: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.860712: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.862590: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.863316: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.868241: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.870052: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.870473: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.872868: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.880162: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:53.893323: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# Iteration 2 out of 10
# 2021-11-18 09:02:58.418965: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.419027: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.419583: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.419643: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.419694: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.421305: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.421544: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.421592: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.421824: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.422129: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.422204: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.424224: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.424367: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.425189: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.425467: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.425504: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.425703: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.426877: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.426989: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.427052: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.427290: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.427468: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.428582: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.429106: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.429971: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.430374: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.431059: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.431185: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.431209: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.431239: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:02:58.431811: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# ...
# 2021-11-18 09:04:25.882517: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.885680: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.889265: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.893670: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.893744: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.895349: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.896644: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.896750: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.896780: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.898704: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.898794: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.898918: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.900935: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.905940: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.906775: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.910010: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.910459: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.910513: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.912627: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.912887: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.912907: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.914057: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.915905: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.919340: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.919424: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.919521: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.920290: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.921310: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.921526: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.922383: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.924578: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.926102: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.926624: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.935577: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.939229: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.940999: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.943762: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.951967: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.955836: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.956969: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.960683: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:04:25.964864: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.

# %%
jnp.savez("GPU-cubature-newtria-T5e3-100runs-mean-median-time",
          gpu_cubature_std_seq_mean_time=gpu_cubature_std_seq_mean_time,
          gpu_cubature_std_seq_median_time=gpu_cubature_std_seq_median_time,
          
          gpu_cubature_std_par_mean_time=gpu_cubature_std_par_mean_time,
          gpu_cubature_std_par_median_time=gpu_cubature_std_par_median_time,
          
          gpu_cubature_sqrt_seq_mean_time=gpu_cubature_sqrt_seq_mean_time,
          gpu_cubature_sqrt_seq_median_time=gpu_cubature_sqrt_seq_median_time,
          
          gpu_cubature_sqrt_par_mean_time=gpu_cubature_sqrt_par_mean_time,
          gpu_cubature_sqrt_par_median_time=gpu_cubature_sqrt_par_median_time)

# %%
plt.figure(figsize=(10,7))
plt.loglog(lengths_space, gpu_cubature_std_seq_mean_time, label="cubature-std-Seq-GPU", linestyle="-.", linewidth=3)
plt.loglog(lengths_space, gpu_cubature_std_par_mean_time, label="cubature-std-Par-GPU", linestyle="-.", linewidth=3)
plt.loglog(lengths_space, gpu_cubature_sqrt_par_mean_time, label="cubature-sqrt-Par-GPU", linestyle="-.", linewidth=3)
plt.loglog(lengths_space, gpu_cubature_sqrt_seq_mean_time, label="cubature-sqrt-Seq-GPU", linestyle="-.", linewidth=3)


plt.grid(True, which="both")
plt.title("cubature-GPU, sequential v.s parallel, std v.s sqrt")
plt.legend()
plt.show()

# %% [markdown]
# # Extended

# %%
def extended_sqrt_seq(y, initial_points_sqrt, iteration):
    sqrt_seq_res = iterated_smoothing(y, chol_init, sqrt_transition_model, sqrt_observation_model,
                                      extended, initial_points_sqrt, False,
                                      criterion=lambda i, *_: i < iteration)
    return sqrt_seq_res


def extended_sqrt_par(y, initial_points_sqrt, iteration):
    sqrt_par_res = iterated_smoothing(y, chol_init, sqrt_transition_model, sqrt_observation_model,
                                      extended, initial_points_sqrt, True,
                                      criterion=lambda i, *_: i < iteration)
    return sqrt_par_res


def extended_std_seq(y, initial_points, iteration):
    std_seq_res = iterated_smoothing(y, init, transition_model, observation_model,
                                     extended, initial_points, False,
                                     criterion=lambda i, *_: i < iteration)
    return std_seq_res


def extended_std_par(y, initial_points, iteration):
    std_par_res = iterated_smoothing(y, init, transition_model, observation_model,
                                     extended, initial_points, True,
                                     criterion=lambda i, *_: i < iteration)
    return std_par_res

# %%
gpu_extended_sqrt_par = jit(extended_sqrt_par, backend="gpu")
gpu_extended_sqrt_seq = jit(extended_sqrt_seq, backend="gpu")
gpu_extended_std_seq = jit(extended_std_seq, backend="gpu")
gpu_extended_std_par = jit(extended_std_par, backend="gpu")

# %%
warnings.filterwarnings("ignore")
gpu_extended_sqrt_par_mean_time, gpu_extended_sqrt_par_median_time = func(gpu_extended_sqrt_par, lengths_space, sqrt=True)
# Out:
# Iteration 1 out of 10
# 2021-11-18 09:11:18.555710: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.569805: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.570819: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.573241: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.574614: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.576792: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.578531: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.579426: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.582380: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.583329: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.583963: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.584214: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.584344: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.585846: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.585968: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.586130: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.586764: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.587654: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.588235: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.588417: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.589075: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.589321: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.589666: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.590412: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.591885: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.592057: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.592156: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.592636: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.592980: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.593457: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.594029: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.594248: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.594388: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.595405: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.595513: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.595562: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.595695: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.596142: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.597077: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.597507: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.599835: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.600663: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.601333: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.601815: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.602046: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.602407: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.602850: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.604081: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.604339: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.604838: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.605582: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.605733: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.605844: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.606286: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.607613: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.607713: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.607810: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.609421: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.609515: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.610136: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.611940: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.612249: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.612353: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.614699: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.615908: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.616506: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.616678: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.616879: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.617899: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.617992: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.618015: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.618385: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.621453: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.621643: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.622056: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.622172: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.623314: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.623447: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.625635: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.628887: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.629198: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.630086: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.631102: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.631782: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.633704: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.636918: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.638948: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.639573: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.645535: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.649123: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.650218: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.651626: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.656590: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.663469: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.665208: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:18.674356: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# Iteration 2 out of 10
# 2021-11-18 09:11:59.136213: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.143058: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.145375: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.145584: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.146065: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.148370: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.150448: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.151408: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.153528: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.154428: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.154730: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.155855: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.156294: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.156658: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.157124: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.158247: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.158690: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.158911: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.158935: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.161491: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.161988: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.162297: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.162449: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.162727: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.162977: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.163369: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.164143: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.164636: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.165581: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:11:59.166228: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# ...
# 2021-11-18 09:31:18.072290: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.073016: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.075454: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.075539: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.075784: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.076048: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.079076: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.081649: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.084185: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.086472: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.087688: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.090435: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.090606: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.091989: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.093934: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.095071: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.095821: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.096696: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.098401: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.098563: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.099564: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.100251: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.100772: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.103530: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.106127: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.107328: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.113377: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.114185: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.117018: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.117831: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.122069: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.122272: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.123468: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.129530: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.130562: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.131690: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.140811: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.148553: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.150053: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.150223: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.153998: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:18.156805: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.

# %%
warnings.filterwarnings("ignore")
gpu_extended_sqrt_seq_mean_time, gpu_extended_sqrt_seq_median_time = func(gpu_extended_sqrt_seq, lengths_space, sqrt=True)
# Out:
# Iteration 1 out of 10
# 2021-11-18 09:31:57.935527: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.936762: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.936861: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.937358: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.938824: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.939689: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.939933: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.941591: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.949287: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.950459: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.950512: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.950551: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.950838: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.951034: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.951058: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.951082: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.951317: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.954258: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.954518: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.954545: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.954565: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.954588: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.955088: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.957724: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.957967: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.958311: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.958708: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.959026: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.959277: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.959341: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.961813: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.961849: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.961870: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.962334: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.962881: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.964289: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.965532: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.966189: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.966749: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.967530: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.968150: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.968440: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.968613: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.968642: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.968927: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.969358: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.970287: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.970572: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.971084: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.971453: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.971722: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.971771: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.971903: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.972176: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.972786: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.972955: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.973136: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.974665: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.975340: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.976724: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.976971: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.977003: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.977058: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.980650: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.980863: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.981055: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.984624: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.984735: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.985474: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.985726: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.989559: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.993591: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.994430: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:57.998588: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.002295: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.005881: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.007650: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.008487: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.010627: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.011403: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.015718: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.017012: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.018299: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.019047: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.021553: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.022523: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.023782: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.025732: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.025942: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.026759: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.028169: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.029132: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.029734: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.030090: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.034652: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:31:58.050234: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# Iteration 2 out of 10
# 2021-11-18 09:32:10.407046: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.407484: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.407996: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.408529: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.408809: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.408997: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.409041: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.409643: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.410277: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.410819: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.410981: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.411006: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.411129: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.411195: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.411247: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.411388: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.411780: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.411901: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.411957: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.412772: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.414133: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.414368: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.414439: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.414717: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.414987: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.415275: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.415642: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.416179: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.416210: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:32:10.416277: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# ...
# 2021-11-18 09:39:06.498452: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.498695: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.498737: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.498875: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.499294: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.499317: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.499655: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.499679: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.499759: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.499812: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.501065: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.501086: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.501493: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.501742: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.502315: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.503234: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.504236: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.505517: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.505651: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.506257: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.506896: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.507103: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.508131: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.508482: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.508543: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.509890: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.510036: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.510965: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.512235: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.512733: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.514071: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.514212: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.514560: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.514584: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.518317: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.519924: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.520298: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.524037: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.531953: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.549610: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.551762: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2021-11-18 09:39:06.556548: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.221, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.

# %%
warnings.filterwarnings("ignore")
gpu_extended_std_seq_mean_time, gpu_extended_std_seq_median_time = func(gpu_extended_std_seq, lengths_space, sqrt=False)

# %%
warnings.filterwarnings("ignore")
gpu_extended_std_par_mean_time, gpu_extended_std_par_median_time = func(gpu_extended_std_par, lengths_space, sqrt=False)

# %%
jnp.savez("GPU-extended-newtria-T5e3-100runs-mean-mediantime",
          gpu_extended_std_seq_mean_time=gpu_extended_std_seq_mean_time,
          gpu_extended_std_seq_median_time=gpu_extended_std_seq_median_time,
          
          gpu_extended_std_par_mean_time=gpu_extended_std_par_mean_time,
          gpu_extended_std_par_median_time=gpu_extended_std_par_median_time,
          
          gpu_extended_sqrt_seq_mean_time=gpu_extended_sqrt_seq_mean_time,
          gpu_extended_sqrt_seq_median_time=gpu_extended_sqrt_seq_median_time,
          
          gpu_extended_sqrt_par_mean_time=gpu_extended_sqrt_par_mean_time,
          gpu_extended_sqrt_par_median_time=gpu_extended_sqrt_par_median_time)

# %%
# with np.load("GPU-cubature-newtria-T5e3-25runs-time.npz") as loaded:
#     gpu_cubature_std_seq_time = loaded["gpu_cubature_std_seq_time"]
#     gpu_cubature_std_par_time = loaded["gpu_cubature_std_par_time"]
#     gpu_cubature_sqrt_seq_time = loaded["gpu_cubature_sqrt_seq_time"]
#     gpu_cubature_sqrt_par_time = loaded["gpu_cubature_sqrt_par_time"]
    
# with np.load("GPU-extended-newtria-T5e3-25runs-time.npz") as loaded:
#     gpu_extended_std_seq_time = loaded["gpu_extended_std_seq_time"]
#     gpu_extended_std_par_time = loaded["gpu_extended_std_par_time"]
#     gpu_extended_sqrt_seq_time = loaded["gpu_extended_sqrt_seq_time"]
#     gpu_extended_sqrt_par_time = loaded["gpu_extended_sqrt_par_time"]

# %%
# T = 5000
# lengths_space = np.logspace(2, int(np.log2(T)), num=10, base=2, dtype=int)

# %%
# fig, axes = plt.subplots(ncols=2, figsize=(18, 7), sharex=True, sharey=True)
# axes[0].loglog(lengths_space, gpu_extended_std_seq_time, label="extended-std-Seq-GPU", linestyle="-.", linewidth=3)
# axes[0].loglog(lengths_space, gpu_extended_std_par_time, label="extended-std-Par-GPU", linestyle="-.", linewidth=3)
# axes[0].loglog(lengths_space, gpu_extended_sqrt_par_time, label="extended-sqrt-Par-GPU", linestyle="-.", linewidth=3)
# axes[0].loglog(lengths_space, gpu_extended_sqrt_seq_time, label="extended-sqrt-Seq-GPU", linestyle="-.", linewidth=3)
# axes[0].grid(True, which="both")
# axes[0].set_title('Extended')
# axes[0].legend()

# axes[1].loglog(lengths_space, gpu_cubature_std_seq_time, label="cubature-std-Seq-GPU", linestyle="-.", linewidth=3)
# axes[1].loglog(lengths_space, gpu_cubature_std_par_time, label="cubature-std-Par-GPU", linestyle="-.", linewidth=3)
# axes[1].loglog(lengths_space, gpu_cubature_sqrt_par_time, label="cubature-sqrt-Par-GPU", linestyle="-.", linewidth=3)
# axes[1].loglog(lengths_space, gpu_cubature_sqrt_seq_time, label="cubature-sqrt-Seq-GPU", linestyle="-.", linewidth=3)
# axes[1].grid(True, which="both")
# axes[1].set_title('Cubeture')
# axes[1].legend();

# %%
# plt.figure(figsize=(15,7))
# plt.loglog(lengths_space, gpu_extended_std_seq_time, label="extended-std-Seq-GPU", linestyle="-.", linewidth=3)
# plt.loglog(lengths_space, gpu_extended_std_par_time, label="extended-std-Par-GPU", linestyle="-.", linewidth=3)
# plt.loglog(lengths_space, gpu_extended_sqrt_par_time, label="extended-sqrt-Par-GPU", linestyle="-.", linewidth=3)
# plt.loglog(lengths_space, gpu_extended_sqrt_seq_time, label="extended-sqrt-Seq-GPU", linestyle="-.", linewidth=3)
# plt.loglog(lengths_space, gpu_cubature_std_seq_time, label="cubature-std-Seq-GPU", linestyle="-.", linewidth=3)
# plt.loglog(lengths_space, gpu_cubature_std_par_time, label="cubature-std-Par-GPU", linestyle="-.", linewidth=3)
# plt.loglog(lengths_space, gpu_cubature_sqrt_par_time, label="cubature-sqrt-Par-GPU", linestyle="-.", linewidth=3)
# plt.loglog(lengths_space, gpu_cubature_sqrt_seq_time, label="cubature-sqrt-Seq-GPU", linestyle="-.", linewidth=3)



# plt.grid(True, which="both")
# plt.title("extended-GPU, sequential v.s parallel, std v.s sqrt")
# plt.legend()
# plt.show()
